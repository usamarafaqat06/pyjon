# %%
fname = input("enter your name");
lname = input( "eneter your last name");
print(lname + " " + fname);
# Out:
# enter your nameyk
# eneter your last nameyk
# yk yk

# %%
import SYS
print(SYS.version)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-c862a9c8524c> in <module>
# ----> 1 import SYS
#       2 print(SYS.version)
#
# ModuleNotFoundError: No module named 'SYS'

# %%
from platform import python_version
print(" Youe python Version is ", python_version());
# Out:
#  Youe python Version is  3.8.8

# %%
from datetime import datetime
now = datetime.now();
print("now =" , now);
# Out:
# now = 2021-10-23 16:24:03.618865
